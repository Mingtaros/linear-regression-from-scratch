# %% [markdown]
# Import module yang digunakan

# %%
import Regression
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %% [markdown]
# Mengambil data dari csv dan memproses data non numeric

# %%
df = Regression.processCSV("car_data.csv")
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000          0
# 1        sx4  2013           4.75           9.54       43000          1
# 2       ciaz  2017           7.25           9.85        6900          0
# 3    wagon r  2011           2.85           4.15        5200          0
# 4      swift  2014           4.60           6.87       42450          1
# ..       ...   ...            ...            ...         ...        ...
# 296     city  2016           9.50          11.60       33988          1
# 297     brio  2015           4.00           5.90       60000          0
# 298     city  2009           3.35          11.00       87934          0
# 299     city  2017          11.50          12.50        9000          1
# 300     brio  2016           5.30           5.90        5464          0
#
#      Seller_Type  Transmission  Owner  Kms_Driven/100  Age
# ...

# %% [markdown]
# Split data 80% train data, 20% test data

# %%
train, test = Regression.splitTestTrain(df, 0.2)
train
# Out:
#               Car_Name  Year  Selling_Price  Present_Price  Kms_Driven  \
# 251               city  2013           5.00           9.90       56701
# 56         etios cross  2015           4.50           7.27       40534
# 268               brio  2017           4.80           5.80       19000
# 208                i20  2017           7.90           8.10        3435
# 157  Yamaha FZ S V 2.0  2015           0.48           0.84       23000
# ..                 ...   ...            ...            ...         ...
# 201                i20  2010           3.25           6.79       58000
# 106     Hyosung GT250R  2014           1.35           3.45       16500
# 263               jazz  2016           6.60           7.70       16002
# 72       corolla altis  2013           7.45          18.61       56001
# 260               city  2016           9.15          13.60       29223
#
#      Fuel_Type  Seller_Type  Transmission  Owner  Kms_Driven/100  Age
# ...

# %%
test
# Out:
#                       Car_Name  Year  Selling_Price  Present_Price  \
# 115  Royal Enfield Classic 350  2015           1.11           1.47
# 187           Honda CB twister  2013           0.25           0.51
# 51                    fortuner  2015          23.00          30.61
# 184           Bajaj Pulsar 150  2008           0.25           0.75
# 227                        i10  2011           2.55           4.43
# ..                         ...   ...            ...            ...
# 55               corolla altis  2009           3.60          15.04
# 10                    alto 800  2017           2.85           3.60
# 83                      innova  2015          12.50          13.46
# 18                     wagon r  2015           3.25           5.09
# 96                      innova  2016          20.75          25.39
#
#      Kms_Driven  Fuel_Type  Seller_Type  Transmission  Owner  Kms_Driven/100  \
# 115       17500          0            1             0      0          175.00
# ...

# %% [markdown]
# Memisahkan attribut yang ingin di proses

# %%
x_var, y_var = Regression.splitVar(train, ["Age", "Present_Price", "Kms_Driven/100"], ["Selling_Price"])
x_var[0:10]
# Out:
# array([[1.0000e+00, 5.0000e+00, 9.9000e+00, 5.6701e+02],
#        [1.0000e+00, 3.0000e+00, 7.2700e+00, 4.0534e+02],
#        [1.0000e+00, 1.0000e+00, 5.8000e+00, 1.9000e+02],
#        [1.0000e+00, 1.0000e+00, 8.1000e+00, 3.4350e+01],
#        [1.0000e+00, 3.0000e+00, 8.4000e-01, 2.3000e+02],
#        [1.0000e+00, 1.2000e+01, 4.1500e+00, 6.5000e+02],
#        [1.0000e+00, 2.0000e+00, 5.7000e+00, 3.4930e+01],
#        [1.0000e+00, 2.0000e+00, 1.5000e+00, 8.7000e+01],
#        [1.0000e+00, 4.0000e+00, 5.2000e-01, 1.9000e+02],
#        [1.0000e+00, 2.0000e+00, 3.7600e+00, 1.0079e+02]])

# %%
y_var[0:10]
# Out:
# array([[5.  ],
#        [4.5 ],
#        [4.8 ],
#        [7.9 ],
#        [0.48],
#        [1.05],
#        [5.25],
#        [1.15],
#        [0.35],
#        [3.  ]])

# %%
x_test, y_test = Regression.splitVar(test, ["Age", "Present_Price", "Kms_Driven/100"], ["Selling_Price"])
x_test[0:10]
# Out:
# array([[1.0000e+00, 3.0000e+00, 1.4700e+00, 1.7500e+02],
#        [1.0000e+00, 5.0000e+00, 5.1000e-01, 3.2000e+02],
#        [1.0000e+00, 3.0000e+00, 3.0610e+01, 4.0000e+02],
#        [1.0000e+00, 1.0000e+01, 7.5000e-01, 2.6000e+02],
#        [1.0000e+00, 7.0000e+00, 4.4300e+00, 5.7000e+02],
#        [1.0000e+00, 3.0000e+00, 1.3090e+01, 6.0076e+02],
#        [1.0000e+00, 3.0000e+00, 3.2000e-01, 3.5000e+02],
#        [1.0000e+00, 3.0000e+00, 1.4790e+01, 1.2900e+02],
#        [1.0000e+00, 2.0000e+00, 3.9500e+00, 2.5000e+02],
#        [1.0000e+00, 2.0000e+00, 1.7800e+00, 6.0000e+01]])

# %%
y_test[0:10]
# Out:
# array([[ 1.11],
#        [ 0.25],
#        [23.  ],
#        [ 0.25],
#        [ 2.55],
#        [ 8.55],
#        [ 0.18],
#        [11.45],
#        [ 2.85],
#        [ 1.2 ]])

# %% [markdown]
# Melakukan Training Data

# %%
coef = Regression.calcCoeff(x_var, y_var)
coef
# Out:
# array([[ 2.78792329e+00],
#        [-4.59602258e-01],
#        [ 5.02062200e-01],
#        [-4.55910507e-05]])

# %% [markdown]
# Melakukan Prediksi

# %%
pred = Regression.predict(x_test, coef)
res = np.c_[y_test, pred]
res
# Out:
# array([[ 1.11      ,  2.13916952],
#        [ 0.25      ,  0.73137459],
#        [23.        , 16.75900403],
#        [ 0.25      , -1.44340631],
#        [ 2.55      ,  1.76885613],
#        [ 8.55      ,  7.95372143],
#        [ 0.18      ,  1.55381956],
#        [11.45      ,  8.82873521],
#        [ 2.85      ,  3.8404667 ],
#        [ 1.2       ,  2.75965403],
#        [ 0.45      ,  2.13960441],
#        [ 0.3       ,  0.76743076],
#        [ 1.05      ,  0.320655  ],
#        [ 0.6       ,  0.42831783],
#        [ 0.48      ,  2.58241234],
#        [18.        , 12.24725206],
#        [23.5       , 19.44184542],
#        [ 0.6       ,  1.07779751],
#        [ 6.5       ,  6.68659687],
#        [ 9.65      ,  9.35547074],
#        [ 0.42      ,  0.85094648],
#        [ 2.5       ,  2.66600584],
#        [ 0.45      ,  0.03672472],
#        [ 0.95      ,  0.90367562],
#        [ 6.85      ,  6.59727072],
#        [11.25      ,  8.68642875],
#        [ 4.15      ,  3.41187912],
# ...

# %% [markdown]
# Menunjukkan akurasi dari algoritma

# %%
r2 = Regression.calc_rsquared(y_test, pred)
r2
# Out:
# SSE = 268.4653
# SST = 2095.5715
# 0.8718892291522082

# %% [markdown]
# Visualisasi Data

# %%
Regression.drawReg(x_test, y_test, coef, 1, "Age", "Selling Price")

# %%
Regression.drawReg(x_test, y_test, coef, 2, "Present_Price", "Selling Price")

# %%
Regression.drawReg(x_test, y_test, coef, 3, "Kms_Driven/100", "Selling Price")
